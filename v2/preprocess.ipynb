# %%
import  pandas as pd
import numpy as np

df = pd.read_excel('dataset.xlsx')

df.dtypes
# Out:
# Seli                                          int64
# mccinfo                                      object
# Şehir                                        object
# İlçe                                         object
# basarili_satis_adet                           int64
# basarili_satis_ciro                         float64
# basarili_iade_adet                            int64
# basarili_iade_ciro                          float64
# Tek Çekim Komisyon Oranı (Güncel)           float64
# Müşteri Skoru                               float64
# bıst100_Kapanış                              object
# bıst100_Açılış                               object
# bıst100_Yüksek                               object
# bıst100_Düşük                                object
# Euro_Kapanış                                 object
# Euro_Açılış                                  object
# Euro_Yüksek                                  object
# Euro_Düşük                                   object
# USD_Kapanış                                  object
# USD_Açılış                                   object
# USD_Yüksek                                   object
# USD_Düşük                                    object
# Tarih                                datetime64[ns]
# Yıl                                           int64
# Ay                                            int64
# Gün                                           int64
# dtype: object

# %%
df.shape
# Out:
# (1707, 26)

# %%
import pandas as pd
import numpy as np
import re

df = pd.read_excel("dataset.xlsx")

df.drop(columns=["Seli", "Tarih"], inplace=True, errors='ignore')

#mccinfo regex "-" öncesindeki dört rakamı alıyoruz
def extract_mcc(value):
    if pd.isnull(value):
        return np.nan
    match = re.match(r"(\d{4})-", value)
    if match:
        return match.group(1)
    else:
        return np.nan

df['mccinfo'] = df['mccinfo'].apply(extract_mcc)

# mccinfo değeri bulunamayan satır sayısı
num_missing_mcc = df['mccinfo'].isnull().sum()
print(f"mccinfo değeri bulunamadığı için silinecek satır sayısı: {num_missing_mcc}")
df = df.dropna(subset=['mccinfo'])

# Sayısal sütunlarda formatlama işlemleri:
numeric_columns = [
    "bıst100_Kapanış", "bıst100_Açılış", "bıst100_Yüksek", "bıst100_Düşük",
    "Euro_Kapanış", "Euro_Açılış", "Euro_Yüksek", "Euro_Düşük",
    "USD_Kapanış", "USD_Açılış", "USD_Yüksek", "USD_Düşük",
]

def fix_numeric_value(s):
    # Önce virgülü noktaya çeviriyoruz
    s = s.replace(',', '.')
    # ikinci noktadan sonrasını sil
    if s.count('.') > 1:
        second_dot = s.find('.', s.find('.') + 1)
        s = s[:second_dot]
    return s

for col in numeric_columns:
    # Her sütunu string'e çevirip, fix fonksiyonunu uyguluyoruz
    df[col] = df[col].astype(str).apply(fix_numeric_value)
    # Ardından float'a çeviriyoruz
    df[col] = df[col].astype(float)

# "Şehir", "İlçe" ve düzenlenmiş "mccinfo" sütunları için one-hot encoding 
categorical_columns = ["Şehir", "İlçe", "mccinfo"]
df = pd.get_dummies(df, columns=categorical_columns, drop_first=True)

print("Ön işleme tamamlandı.")
# Out:
# mccinfo değeri bulunamadığı için silinecek satır sayısı: 15
# Ön işleme tamamlandı.

# %%
df.shape
# Out:
# (1692, 470)

# %%
df.head()
# Out:
#    basarili_satis_adet  basarili_satis_ciro  basarili_iade_adet  \
# 0               247520         1.045249e+08                 994
# 1                10683         2.685102e+06                  10
# 2                  289         3.024150e+04                  67
# 3                    3         1.867700e+04                   0
# 4                  856         6.864042e+06                   5
#
#    basarili_iade_ciro  Tek Çekim Komisyon Oranı (Güncel)  Müşteri Skoru  \
# 0           560218.63                               3.49          58.62
# 1             5521.15                               3.60          64.08
# 2             3385.00                               3.90          61.36
# 3                0.00                               3.15          51.42
# 4             9880.55                               2.56          44.88
#
#    bıst100_Kapanış  bıst100_Açılış  bıst100_Yüksek  bıst100_Düşük  \
# 0            1.492           1.484           1.500          1.471
# 1            1.408           1.405           1.412          1.400
# 2            1.375           1.393           1.398          1.374
# 3            1.392           1.381           1.397          1.381
# 4            1.392           1.381           1.397          1.381
#
#    Euro_Kapanış  Euro_Açılış  Euro_Yüksek  Euro_Düşük  USD_Kapanış  \
# 0        8.6684       8.8803       8.8847      8.6334       7.1883
# 1        9.6543       9.5982       9.7193      9.5847       8.0567
# 2        9.6964       9.7186       9.7850      9.6501       8.1421
# 3        9.9102      10.0075      10.0388      9.8691       8.1977
# 4        9.9102      10.0075      10.0388      9.8691       8.1977
#
#    USD_Açılış  USD_Yüksek  USD_Düşük   Yıl  Ay  Gün  Şehir_ADIYAMAN  \
# 0      7.3151      7.3177     7.1557  2021   2    1           False
# 1      8.0205      8.1204     8.0082  2021   4   16           False
# 2      8.1655      8.2371     8.1015  2021   4   12           False
# 3      8.2827      8.3113     8.1688  2021   4   27           False
# 4      8.2827      8.3113     8.1688  2021   4   27           False
#
#    Şehir_AFYON  Şehir_AKSARAY  Şehir_ANKARA  Şehir_ANTALYA  Şehir_ARTVİN  \
# 0        False          False         False          False         False
# 1        False          False         False          False         False
# 2        False          False         False          False         False
# 3        False          False         False          False         False
# 4        False          False         False          False         False
#
#    Şehir_AYDIN  Şehir_AĞRI  Şehir_BALIKESİR  Şehir_BARTIN  Şehir_BATMAN  \
# 0        False       False            False         False         False
# 1        False       False            False         False         False
# 2        False       False            False         False         False
# 3        False       False            False         False         False
# 4        False       False            False         False         False
#
#    Şehir_BOLU  Şehir_BURDUR  Şehir_BURSA  Şehir_BİLECİK  Şehir_DENİZLİ  \
# 0       False         False        False          False          False
# 1       False         False        False          False          False
# 2       False         False        False          False          False
# 3       False         False        False          False          False
# 4       False         False        False          False          False
#
#    Şehir_DÜZCE  Şehir_DİYARBAKIR  Şehir_EDİRNE  Şehir_ELAZIĞ  Şehir_ERZURUM  \
# 0        False             False         False         False          False
# 1        False             False         False         False          False
# 2        False             False         False         False          False
# 3        False             False         False         False          False
# 4        False             False         False         False          False
#
#    Şehir_ESKİŞEHİR  Şehir_GAZİANTEP  Şehir_GÜMÜŞHANE  Şehir_GİRESUN  \
# 0            False            False            False          False
# 1            False            False            False          False
# 2            False            False            False          False
# 3            False            False            False          False
# 4            False            False            False          False
#
#    Şehir_HATAY  Şehir_ISPARTA  Şehir_KAHRAMANMARAŞ  Şehir_KARABÜK  Şehir_KARS  \
# 0        False          False                False          False       False
# 1        False          False                False          False       False
# 2        False          False                False          False       False
# 3        False          False                False          False       False
# 4        False          False                False          False       False
#
#    Şehir_KASTAMONU  Şehir_KAYSERİ  Şehir_KIRKLARELİ  Şehir_KIRŞEHİR  \
# 0            False          False             False           False
# 1            False          False             False           False
# 2            False          False             False           False
# 3            False          False             False           False
# 4            False          False             False           False
#
#    Şehir_KOCAELİ  Şehir_KONYA  Şehir_KÜTAHYA  Şehir_MALATYA  Şehir_MANYSA  \
# 0          False        False          False          False         False
# 1          False        False          False          False         False
# 2          False        False          False          False         False
# 3          False        False          False          False         False
# 4          False        False          False          False         False
#
#    Şehir_MARDİN  Şehir_MERSİN  Şehir_MUĞLA  Şehir_ORDU  Şehir_OSMANİYE  \
# 0         False         False        False       False           False
# 1         False         False        False       False           False
# 2         False         False        False       False           False
# 3         False         False        False       False           False
# 4         False         False        False       False           False
#
#    Şehir_RİZE  Şehir_SAKARYA  Şehir_SAMSUN  Şehir_SİNOP  Şehir_SİVAS  \
# 0       False          False         False        False        False
# 1       False          False         False        False        False
# 2       False          False         False        False        False
# 3       False          False         False        False        False
# 4       False          False         False        False        False
#
#    Şehir_SİİRT  Şehir_TEKİRDAĞ  Şehir_TOKAT  Şehir_TRABZON  Şehir_UŞAK  \
# 0        False           False        False          False       False
# 1        False           False        False          False       False
# 2        False           False        False          False       False
# 3        False           False        False          False       False
# 4        False           False        False          False       False
#
#    Şehir_YALOVA  Şehir_ZONGULDAK  Şehir_ÇANAKKALE  Şehir_ÇANKIRI  Şehir_ÇORUM  \
# 0         False            False            False          False        False
# 1         False            False            False          False        False
# 2         False            False            False          False        False
# 3         False            False            False          False        False
# 4         False            False            False          False        False
#
#    Şehir_İSTANBUL  Şehir_İZMİR  Şehir_ŞANLIURFA  İlçe_19 Mayıs  İlçe_ALTINDAĞ  \
# 0            True        False            False          False          False
# 1            True        False            False          False          False
# 2            True        False            False          False          False
# 3            True        False            False          False          False
# 4            True        False            False          False          False
#
#    İlçe_ALTINORDU  İlçe_ATAŞEHİR  İlçe_Adapazarı  İlçe_Akdeniz  İlçe_Akhisar  \
# 0           False          False           False         False         False
# 1           False          False           False         False         False
# 2           False          False           False         False         False
# 3           False          False           False         False         False
# 4           False          False           False         False         False
#
#    İlçe_Aksu  İlçe_Akyurt  İlçe_Akçaabat  İlçe_Alaca  İlçe_Alanya  \
# 0      False        False          False       False        False
# 1      False        False          False       False        False
# 2      False        False          False       False        False
# 3      False        False          False       False        False
# 4      False        False          False       False        False
#
#    İlçe_Alaşehir  İlçe_Aliağa  İlçe_Altıeylül  İlçe_Altındağ  İlçe_Altınova  \
# 0          False        False           False          False          False
# 1          False        False           False          False          False
# 2          False        False           False          False          False
# 3          False        False           False          False          False
# 4          False        False           False          False          False
#
#    İlçe_Ankara  İlçe_Antakya  İlçe_Arifiye  İlçe_Arnavutköy  İlçe_Arsuz  \
# 0        False         False         False            False       False
# 1        False         False         False            False       False
# 2        False         False         False            False       False
# 3        False         False         False            False       False
# 4        False         False         False            False       False
#
#    İlçe_Artuklu  İlçe_Atakum  İlçe_Ataşehir  İlçe_Avcılar  İlçe_Ayvalık   \
# 0         False        False          False         False          False
# 1         False        False          False         False          False
# 2         False        False          False         False          False
# 3         False        False          False         False          False
# 4         False        False          False         False          False
#
#    İlçe_Aziziye  İlçe_BAHÇELİEVLER  İlçe_BEYOĞLU  İlçe_Bafra  \
# 0         False              False         False       False
# 1         False              False         False       False
# 2         False              False         False       False
# 3         False              False         False       False
# 4         False              False         False       False
#
#    İlçe_Bahçelievler  İlçe_Bahçeşehir  İlçe_Bakırköy  İlçe_Balçova  \
# 0              False            False          False         False
# 1              False            False          False         False
# 2              False            False          False         False
# 3              False            False          False         False
# 4              False            False          False         False
#
#    İlçe_Bandırma  İlçe_Battalgazi  İlçe_Bayraklı  İlçe_Bayrampaşa  \
# 0          False            False          False            False
# 1          False            False          False            False
# 2          False            False          False            False
# 3          False            False          False            False
# 4          False            False          False            False
#
#    İlçe_Bağcılar  İlçe_Bağcılar   İlçe_Başakşehir  İlçe_Başiskele  \
# 0          False           False            False           False
# 1          False           False            False           False
# 2          False           False            False           False
# 3          False           False            False           False
# 4          False           False            False           False
#
#    İlçe_Bergama  İlçe_Beykoz  İlçe_Beykoz   İlçe_Beylikdüzü  İlçe_Beyoğlu  \
# 0         False        False         False            False         False
# 1         False        False          True            False         False
# 2         False        False         False            False         False
# 3         False        False         False            False         False
# 4         False        False         False            False         False
#
#    İlçe_Beşiktaş  İlçe_Biga  İlçe_Bigadiç  İlçe_Bodrum  İlçe_Bolvadin  \
# 0          False      False         False        False          False
# 1          False      False         False        False          False
# 2          False      False         False        False          False
# 3          False      False         False        False          False
# 4          False      False         False        False          False
#
#    İlçe_Bornova  İlçe_Borçka  İlçe_Bozüyük  İlçe_Buca  İlçe_Bucak  \
# 0         False        False         False      False       False
# 1         False        False         False      False       False
# 2         False        False         False      False       False
# 3         False        False         False      False       False
# 4         False        False         False      False       False
#
#    İlçe_Bulancak  İlçe_Buldan  İlçe_Büyükçekmece  İlçe_Darıca  İlçe_Demirci  \
# 0          False        False              False        False         False
# 1          False        False              False        False         False
# 2          False        False              False        False         False
# 3          False        False              False        False         False
# 4          False        False              False        False         False
#
#    İlçe_Derince  İlçe_Didim  İlçe_Dulkadiroğlu  İlçe_Döşemealtı  İlçe_Edremit  \
# 0         False       False              False            False         False
# 1         False       False              False            False         False
# 2         False       False              False            False         False
# 3         False       False              False            False         False
# 4         False       False              False            False         False
#
#    İlçe_Efeler  İlçe_Elmadağ  İlçe_Erbaa  İlçe_Erenler  İlçe_Ereğli  \
# 0        False         False       False         False        False
# 1        False         False       False         False        False
# 2        False         False       False         False        False
# 3        False         False       False         False        False
# 4        False         False       False         False        False
#
#    İlçe_Ergene  İlçe_Esenler  İlçe_Esenyurt  İlçe_Eskil  İlçe_Etimesgut  \
# 0        False         False          False       False           False
# 1        False         False          False       False           False
# 2        False         False          False       False           False
# 3        False         False          False       False           False
# 4        False         False          False       False           False
#
#    İlçe_Eyyübiye  İlçe_Eyüpsultan  İlçe_FATİH  İlçe_Fatih  İlçe_Fatsa  \
# 0          False            False       False       False       False
# 1          False            False       False       False       False
# 2          False            False       False       False       False
# 3          False            False       False       False       False
# 4          False            False       False       False       False
#
#    İlçe_Fethiye  İlçe_Gaziemir  İlçe_Gaziosmanpaşa  İlçe_Gazipaşa  İlçe_Gebze  \
# 0         False          False               False          False       False
# 1         False          False               False          False       False
# 2         False          False               False          False       False
# 3         False          False               False          False       False
# 4         False          False               False          False       False
#
#    İlçe_Gelibolu  İlçe_Gerze  İlçe_Gökçeada  İlçe_Gölbaşı  İlçe_Gölcük  \
# 0          False       False          False         False        False
# 1          False       False          False         False        False
# 2          False       False          False         False        False
# 3          False       False          False         False        False
# 4          False       False          False         False        False
#
#    İlçe_Gönen  İlçe_Güngören  İlçe_Güzelbahçe  İlçe_Hacılar  İlçe_Hendek  \
# 0       False          False            False         False        False
# 1       False          False            False         False        False
# 2       False          False            False         False        False
# 3       False          False            False         False        False
# 4       False          False            False         False        False
#
#    İlçe_Honaz  İlçe_Hüyük  İlçe_KADIKÖY  İlçe_KARTAL  İlçe_KAĞITHANE  \
# 0       False       False         False        False           False
# 1       False       False         False        False           False
# 2       False       False         False        False           False
# 3       False       False         False        False           False
# 4       False       False         False        False           False
#
#    İlçe_Kadıköy  İlçe_Kalekapı  İlçe_Kapaklı  İlçe_Karabağlar  İlçe_Karaköprü  \
# 0         False          False         False            False           False
# 1         False          False         False            False           False
# 2         False          False         False            False           False
# 3          True          False         False            False           False
# 4         False          False         False            False           False
#
#    İlçe_Karamürsel  İlçe_Karatay  İlçe_Karesi  İlçe_Kartal  İlçe_Kartepe  \
# 0            False         False        False        False         False
# 1            False         False        False        False         False
# 2            False         False        False        False         False
# 3            False         False        False        False         False
# 4            False         False        False        False         False
#
#    İlçe_Karşıkaya  İlçe_Karşıyaka  İlçe_Kayapınar  İlçe_Kağıthane  \
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False
# 4           False           False           False           False
#
#    İlçe_Kemalpaşa  İlçe_Kepez  İlçe_Keçiören  İlçe_Keşan  İlçe_Kocaeli  \
# 0           False       False          False       False         False
# 1           False       False          False       False         False
# 2           False       False          False       False         False
# 3           False       False          False       False         False
# 4           False       False          False       False         False
#
#    İlçe_Kocasinan  İlçe_Konak  İlçe_Konyaaltı  İlçe_Kozlu  İlçe_Kozluk  \
# 0           False       False           False       False        False
# 1           False       False           False       False        False
# 2           False       False           False       False        False
# 3           False       False           False       False        False
# 4           False       False           False       False        False
#
#    İlçe_Kuşadası  İlçe_Körfez  İlçe_Köyceğiz  İlçe_Küçükçekmece  \
# 0          False        False          False              False
# 1          False        False          False              False
# 2          False        False          False              False
# 3          False        False          False              False
# 4          False        False          False              False
#
#    İlçe_Kızılcahamam  İlçe_Lüleburgaz  İlçe_MELİKGAZİ  İlçe_MERKEZ  \
# 0              False            False           False        False
# 1              False            False           False        False
# 2              False            False           False        False
# 3              False            False           False        False
# 4              False            False           False        False
#
#    İlçe_Maltepe  İlçe_Maltepe   İlçe_Mamak  İlçe_Manavgat  İlçe_Marmaris  \
# 0         False          False       False          False          False
# 1         False          False       False          False          False
# 2         False          False       False          False          False
# 3         False          False       False          False          False
# 4         False          False       False          False          False
#
#    İlçe_Melikgazi  İlçe_Menderes  İlçe_Menemen  İlçe_Menteşe  İlçe_Meram  \
# 0           False          False         False         False       False
# 1           False          False         False         False       False
# 2           False          False         False         False       False
# 3           False          False         False         False       False
# 4           False          False         False         False       False
#
#    İlçe_Merkez  İlçe_Merkezefendi  İlçe_Mezitli  İlçe_Mucur  İlçe_Mudanya  \
# 0        False              False         False       False         False
# 1        False              False         False       False         False
# 2        False              False         False       False         False
# 3        False              False         False       False         False
# 4        False              False         False       False         False
#
#    İlçe_Muratpaşa  İlçe_Narlıdere  İlçe_Nazilli  İlçe_Nilüfer  \
# 0           False           False         False         False
# 1           False           False         False         False
# 2           False           False         False         False
# 3           False           False         False         False
# 4           False           False         False         False
#
#    İlçe_Odunpazarı  İlçe_Onikişubat  İlçe_Ortaca  İlçe_Ortahisar  \
# 0            False            False        False           False
# 1            False            False        False           False
# 2            False            False        False           False
# 3            False            False        False           False
# 4            False            False        False           False
#
#    İlçe_Osmaneli  İlçe_Osmangazi  İlçe_Oğuzeli  İlçe_Palandöken  \
# 0          False           False         False            False
# 1          False           False         False            False
# 2          False           False         False            False
# 3          False           False         False            False
# 4          False           False         False            False
#
#    İlçe_Pamukkale  İlçe_Pamukova  İlçe_Pendik  İlçe_Piraziz  İlçe_Polatlı  \
# 0           False          False        False         False         False
# 1           False          False        False         False         False
# 2           False          False        False         False         False
# 3           False          False        False         False         False
# 4           False          False        False         False         False
#
#    İlçe_Pursaklar  İlçe_SARIYER  İlçe_SELÇUKLU  İlçe_Safranbolu  İlçe_Salihli  \
# 0           False         False          False            False         False
# 1           False         False          False            False         False
# 2           False         False          False            False         False
# 3           False         False          False            False         False
# 4           False         False          False            False         False
#
#    İlçe_Sancaktepe  İlçe_Sapanca  İlçe_Sarıyer  İlçe_Seferihisar  İlçe_Selçuk  \
# 0            False         False         False             False        False
# 1            False         False         False             False        False
# 2            False         False         False             False        False
# 3            False         False         False             False        False
# 4            False         False         False             False        False
#
#    İlçe_Selçuklu  İlçe_Serdivan  İlçe_Seyhan  İlçe_Silifke  İlçe_Silivri  \
# 0          False          False        False         False         False
# 1          False          False        False         False         False
# 2          False          False        False         False         False
# 3          False          False        False         False         False
# 4          False          False        False         False         False
#
#    İlçe_Sinanpaşa  İlçe_Sincan  İlçe_Sivas  İlçe_Sivaslı  İlçe_Sultanbeyli  \
# 0           False        False       False         False             False
# 1           False        False       False         False             False
# 2           False        False       False         False             False
# 3           False        False       False         False             False
# 4           False        False       False         False             False
#
#    İlçe_Sultangazi  İlçe_Sur  İlçe_Süleymanpaşa  İlçe_Sındırgı  İlçe_Talas  \
# 0            False     False              False          False       False
# 1            False     False              False          False       False
# 2            False     False              False          False       False
# 3            False     False              False          False       False
# 4            False     False              False          False       False
#
#    İlçe_Tarsus  İlçe_Tavşanlı  İlçe_Taşköprü  İlçe_Tekkeköy  İlçe_Tepebaşı  \
# 0        False          False          False          False          False
# 1        False          False          False          False          False
# 2        False          False          False          False          False
# 3        False          False          False          False          False
# 4        False          False          False          False          False
#
#    İlçe_Terme  İlçe_Torbalı  İlçe_Toroslar  İlçe_Tuzla  İlçe_Ulus  İlçe_Urla  \
# 0       False         False          False       False      False      False
# 1       False         False          False       False      False      False
# 2       False         False          False       False      False      False
# 3       False         False          False       False      False      False
# 4       False         False          False       False      False      False
#
#    İlçe_YENİMAHALLE  İlçe_Yakutiye  İlçe_Yatağan  İlçe_Yenimahalle  \
# 0             False          False         False             False
# 1             False          False         False             False
# 2             False          False         False             False
# 3             False          False         False             False
# 4             False          False         False             False
#
#    İlçe_Yenişehir  İlçe_Yeşilyurt  İlçe_Yunusemre  İlçe_Yüreğir  \
# 0           False           False           False         False
# 1           False           False           False         False
# 2           False           False           False         False
# 3           False           False           False         False
# 4           False           False           False         False
#
#    İlçe_Yıldırım  İlçe_Zeytinburnu  İlçe_Zile  İlçe_ Altındağ  \
# 0          False             False      False           False
# 1          False             False      False           False
# 2          False             False      False           False
# 3          False             False      False           False
# 4          False             False      False           False
#
#    İlçe_ Eyüpsultan  İlçe_ÇANKAYA  İlçe_ÇATALCA  İlçe_Çal  İlçe_Çankaya  \
# 0             False         False         False     False         False
# 1             False         False         False     False         False
# 2             False         False         False     False         False
# 3             False         False         False     False         False
# 4             False         False         False     False         False
#
#    İlçe_Çaycuma  İlçe_Çekmeköy  İlçe_Çeltik  İlçe_Çerkezköy  İlçe_Çeşme  \
# 0         False          False        False           False       False
# 1         False          False        False           False       False
# 2         False          False        False           False       False
# 3         False          False        False           False       False
# 4         False          False        False           False       False
#
#    İlçe_Çiftlikköy  İlçe_Çine  İlçe_Çiğli  İlçe_Çorlu  İlçe_Çubuk  \
# 0            False      False       False       False       False
# 1            False      False       False       False       False
# 2            False      False       False       False       False
# 3            False      False       False       False       False
# 4            False      False       False       False       False
#
#    İlçe_Çukurova  İlçe_Ödemiş  İlçe_ÜMRANİYE  İlçe_Ümraniye  İlçe_Ünye  \
# 0          False        False          False          False      False
# 1          False        False          False          False      False
# 2          False        False          False          False      False
# 3          False        False          False          False      False
# 4          False        False          False           True      False
#
#    İlçe_Üsküdar  İlçe_İlkadım  İlçe_İncesu  İlçe_İnegöl  İlçe_İskenderun  \
# 0         False         False        False        False            False
# 1         False         False        False        False            False
# 2         False         False        False        False            False
# 3         False         False        False        False            False
# 4         False         False        False        False            False
#
#    İlçe_İzmit  İlçe_Şahinbey  İlçe_Şarköy  İlçe_Şehitkamil  İlçe_Şehzadeler  \
# 0       False          False        False            False            False
# 1       False          False        False            False            False
# 2       False          False        False            False            False
# 3       False          False        False            False            False
# 4       False          False        False            False            False
#
#    İlçe_Şile  İlçe_Şişli  İlçe_ŞİŞLİ  mccinfo_1711  mccinfo_1731  \
# 0      False       False        True         False         False
# 1      False       False       False         False         False
# 2      False        True       False         False         False
# 3      False       False       False         False         False
# 4      False       False       False         False         False
#
#    mccinfo_1750  mccinfo_1761  mccinfo_1799  mccinfo_2842  mccinfo_4121  \
# 0         False         False         False         False         False
# 1         False         False         False         False         False
# 2         False         False         False         False         False
# 3         False         False         False         False         False
# 4         False         False         False         False         False
#
#    mccinfo_4214  mccinfo_4215  mccinfo_4722  mccinfo_4789  mccinfo_4812  \
# 0         False         False         False         False         False
# 1         False         False         False         False         False
# 2         False         False         False         False         False
# 3         False         False         False         False         False
# 4         False         False         False         False         False
#
#    mccinfo_4900  mccinfo_5013  mccinfo_5021  mccinfo_5039  mccinfo_5045  \
# 0         False         False         False         False         False
